# %%
import pandas as pd
import numpy as np
import pymongo
from pymongo import MongoClient
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load in data

# %% [markdown]
# #### Get data from user selection

# %%
#For now just use the exported csv
user_df = pd.read_csv('newway_data.csv')

# %%
user_df = user_df.drop(columns = ['uri', 'duration_ms'])

# %%
user_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.624   0.886    4    -6.046     1       0.0351        0.1000
# 1         0.623   0.766    4    -7.445     1       0.0531        0.1030
# 2         0.475   0.624   11    -8.698     0       0.0291        0.0258
# 3         0.646   0.611    0    -6.516     1       0.0272        0.1710
# 4         0.543   0.526    2    -9.703     1       0.0582        0.0447
#
#    instrumentalness  liveness  valence    tempo
# 0          0.941000    0.0943    0.772  155.249
# 1          0.019300    0.1580    0.550  153.150
# 2          0.000229    0.1810    0.779  173.078
# 3          0.000000    0.0634    0.272  109.051
# 4          0.053300    0.0778    0.384  153.000

# %%
user_sub = user_df[['energy', 'liveness', 'danceability', 'key', 'mode', 'speechiness', 
                    'loudness', 'acousticness', 'instrumentalness', 'valence', 'tempo']]

# %%
vibe_np = user_sub.agg('mean').to_numpy()
vibe = user_sub.agg('mean').to_frame()

# %%
vibe
# Out:
#                            0
# energy              0.677938
# liveness            0.213422
# danceability        0.581875
# key                 5.187500
# mode                0.562500
# speechiness         0.052166
# loudness           -7.249156
# acousticness        0.172883
# instrumentalness    0.136619
# valence             0.591938
# tempo             118.406625

# %% [markdown]
# #### Get Reddit data from MongoDB

# %%
with open('db_pass.txt', 'r') as f:
    db_pass = f.read()

# %%
client = pymongo.MongoClient()

# %%
#Specify database and collection
db = client['RedditCollect']
collection = db['indieheads']

# %%
db.list_collection_names()
# Out:
# ['indieheads', 'Alternativerock']

# %%
cursor = collection.find({})
reddit_df = pd.DataFrame(list(cursor))

# %% [raw]
# What Features are categorized as
# ------------------------------------------------------
# Mood: Danceability, Valence, Energy, Tempo
# Properties: Loudness, Speechiness, Instrumentalness
# Context: Liveness, Acousticness

# %%
#Select track features of interest
#First try the feature in each category with the highest variation
reddit_features = reddit_df[['energy', 'danceability', 'key', 'speechiness', 
                             'acousticness', 'instrumentalness', 'valence', 'tempo']]

#Drop features the may not be important
# 'danceability', 'energy', 'key', 'mode', 'speechiness', 'loudness'
# 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo'

# %%
plt.scatter(reddit_features.energy, reddit_features.loudness, c=reddit_features.liveness, alpha = 0.6, s=10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-e099e173fe86> in <module>
# ----> 1 plt.scatter(reddit_features.energy, reddit_features.loudness, c=reddit_features.liveness, alpha = 0.6, s=10)
#
# ~/Applications/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'liveness'

# %% [markdown]
# ## Preprocessing

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale_cols = list(reddit_features.columns)

#create and fit scaler
scaler = StandardScaler()
scaler.fit(reddit_features[scale_cols])

#scale selected data
reddit_features[scale_cols] = scaler.transform(reddit_features[scale_cols])
# Out:
# /Users/treycapps/Applications/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3678: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = igetitem(value, i)

# %%
reddit_features.head()
# Out:
#      energy  loudness  liveness
# 0  0.230686 -0.211590 -0.136565
# 1 -0.509523  0.851861 -0.681291
# 2 -2.083638 -1.954533 -0.563376
# 3 -1.427757 -1.574393 -0.541674
# 4  0.272850  0.886232 -0.577844

# %% [markdown]
# ## Model Building

# %% [markdown]
# #### K-Means

# %%
from sklearn.cluster import KMeans

#        [ 1.05990726e+00,  1.12594926e+00, -2.59544197e-01],
#        [ 1.60335171e+00,  9.59087355e-01,  8.76207499e-01],
#        [ 1.57992738e+00,  6.03330719e-01,  1.31748682e+00],
#        [ 8.07702943e-02, -4.88408189e-02, -8.87462968e-01],
#        [-8.32000118e-02,  1.26540446e-01,  8.68973412e-01],
#        [ 1.32303819e-01,  2.47574083e-01, -3.82523680e-01],
#        [ 1.50028466e+00,  7.85174945e-01,  1.11493238e+00],
#        [-4.29880088e-01,  3.24542075e-01, -3.75289592e-01],
#        [ 2.54110332e-01,  7.37290278e-01, -6.06780384e-01],
#        [-2.06021342e+00, -2.49301523e+00, -5.48907686e-01],
#        [-1.67527598e-01, -7.61822946e-01, -9.31590900e-01],
#        [-1.01548832e+00, -8.25865016e-01, -5.70609948e-01],
#        [ 1.60335171e+00,  9.59087355e-01,  8.76207499e-01],
#        [-8.56202883e-01, -9.98602342e-01, -4.98269075e-01],
#        [-1.29270235e-02,  3.19841740e-01, -4.04225941e-01],
#        [-2.39283889e+00, -2.44513056e+00, -5.63375860e-01],
#        [ 6.52323933e-01,  3.49218836e-01,  1.18727325e+00],
#        [ 1.13018025e+00,  5.79535271e-01,  5.00034963e-01],
#        [ 4.18080638e-01,  7.74892962e-01,  1.70089344e+00],
#        [ 2.35370869e-01,  4.28243225e-01,  2.90898601e+00],
#        [-5.04059506e-02, -1.33446856e-01, -5.48907686e-01],
#        [ 4.64929297e-01,  1.98155775e-03,  7.67696190e-01],
#        [-1.20756783e+00, -9.09002199e-01, -5.56141773e-01],
#        [-2.62380278e+00, -3.82115376e+00, -6.06780384e-01],
#        [-9.35845604e-01, -7.15407134e-01, -7.16015101e-01],
#        [ 1.64551550e+00,  1.35744078e+00, -2.95714633e-01],
#        [-2.03210422e+00, -1.75212486e+00, -4.33162290e-01],
#        [-8.28093688e-01,  7.63056114e-02, -5.19971337e-01],
#        [ 3.89971443e-01, -7.85116861e-02,  8.11703096e-03],
#        [ 6.57008799e-01,  4.96104318e-01, -7.36270545e-01],
#        [-5.42316869e-01,  3.77420849e-01, -5.19971337e-01],
#        [ 1.20045324e+00,  4.85528563e-01, -5.63375860e-01]])

# %%
k = 15
kmeans = KMeans(n_clusters = k, init = 'random', random_state = 1)
y_pred = kmeans.fit(X)

# %%
#Use elbow method to determine optimal clusters
distort = []
max_cluster = 12
for i in range(1, max_cluster):
    km = KMeans(n_clusters=i, init='k-means++', random_state=42)
    km.fit_predict(X)
    distort.append(km.inertia_)

# plot
plt.plot(range(1, max_cluster), distort, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.show()

# %%
reddit_df['cluster'] = list(y_pred.labels_)

# %%
np.array([vibe])
# Out:
# array([[ 0.6779375 , -7.24915625,  0.21342188]])

# %%
user_cluster = kmeans.predict(np.array([vibe]))
user_cluster
# Out:
# array([0], dtype=int32)

# %%
reddit_df['cluster'].value_counts()
# Out:
# 0     34
# 7     32
# 12    24
# 2     24
# 1     23
# 10    23
# 3     19
# 4     17
# 6     16
# 5     14
# 13    13
# 11     7
# 9      7
# 14     4
# 8      3
# Name: cluster, dtype: int64

# %%
suggested = reddit_df[reddit_df['cluster'] == 0]
top_suggested = suggested.sort_values(by = 'upvotes', ascending = False)
top_suggested.head(15)
# Out:
#         _id       created  upvotes  \
# 154  u22n7a  1.649780e+09      614
# 37   uav6an  1.650808e+09      176
# 170  u12773  1.649663e+09      140
# 109  u78nuh  1.650384e+09      123
# 26   ucc1f1  1.650978e+09       77
# 33   ubob8a  1.650902e+09       57
# 102  u7h0ha  1.650406e+09       54
# 236  twtejj  1.649160e+09       44
# 47   u96s5e  1.650604e+09       29
# 46   u97cy3  1.650606e+09       25
# 15   ucux7q  1.651033e+09       23
# 14   ucvno7  1.651035e+09       19
# 125  u4ahrn  1.650036e+09       12
# 23   ucf4g0  1.650987e+09       10
# 13   ucvwi6  1.651036e+09        8
#
#                                                    url   subreddit  \
# 154  https://open.spotify.com/album/1pBQcc31ztdgf8d...  indieheads
# 37   https://open.spotify.com/track/1gaByCFB1qArGJU...  indieheads
# 170  https://open.spotify.com/track/4EGMLBvaIIHNYuT...  indieheads
# 109  https://open.spotify.com/track/408MabGZjrEvunW...  indieheads
# 26   https://open.spotify.com/track/77cY2Nxpu0fyc1G...  indieheads
# 33   https://music.apple.com/ca/album/see-you-soon/...  indieheads
# 102  https://music.apple.com/fr/album/graves-single...  indieheads
# 236        https://www.youtube.com/watch?v=cP-fyWI4dn8  indieheads
# 47   https://open.spotify.com/track/4hFwJpN49gRhIXD...  indieheads
# 46   https://music.apple.com/us/album/birthdays/161...  indieheads
# 15                        https://youtu.be/jC5GxpxQS9w  indieheads
# 14   https://open.spotify.com/album/345yVSKKqobwMLX...  indieheads
# 125  https://music.apple.com/us/album/hold-on-magno...  indieheads
# 23   https://www.youtube.com/watch?v=pYrImTkKBBc&ab...  indieheads
# 13   https://open.spotify.com/track/5wM6LOw2U6XeIFH...  indieheads
#
#                      artist_all                    track  danceability  \
# 154                   Jamie xx         LET'S DO IT AGAIN         0.660
# 37   DJ Sabrina The Teenage DJ                  Call You         0.575
# 170                  Jockstrap       Concrete Over Water         0.318
# 109             Fontaines D.C.             Roman Holiday         0.491
# 26                      Mogwai                   Boltfor         0.383
# 33                 beabadoobee              See you Soon         0.593
# 102                Purity Ring                    graves         0.569
# 236                  Horsegirl    World of Pots and Pans         0.180
# 47              Kate Bollinger   Look at it in the Light         0.678
# 46                  Craig Finn                 Birthdays         0.500
# 15              The Black Keys             It Ain't Over         0.756
# 14                        Dehd          Empty in My Mind         0.772
# 125                     Sylvie          Hold On Magnolia         0.600
# 23                   Mikey Erg    Almost Like Judee Sill         0.174
# 13                      Madeon             Love You Back         0.510
#
#      energy  key  ...  mode  speechiness  acousticness  instrumentalness  \
# 154   0.837    2  ...     0       0.0294      0.242000          0.876000
# 37    0.796    6  ...     1       0.1410      0.184000          0.000000
# 170   0.375    1  ...     0       0.0360      0.748000          0.001320
# 109   0.672    0  ...     1       0.0329      0.000647          0.000014
# 26    0.591    0  ...     1       0.0355      0.033300          0.589000
# 33    0.544    2  ...     1       0.0257      0.476000          0.602000
# 102   0.582    8  ...     1       0.0664      0.422000          0.003790
# 236   0.659    4  ...     1       0.0374      0.525000          0.474000
# 47    0.422    0  ...     1       0.0384      0.379000          0.001040
# 46    0.599    5  ...     1       0.0371      0.365000          0.000000
# 15    0.555    2  ...     1       0.0355      0.031700          0.000002
# 14    0.674    5  ...     0       0.0461      0.055200          0.430000
# 125   0.451    4  ...     1       0.0232      0.785000          0.734000
# 23    0.964   11  ...     0       0.1180      0.000271          0.000169
# 13    0.715   11  ...     1       0.0366      0.004850          0.000115
#
#      liveness  valence    tempo                                   uri  \
# 154    0.0704   0.3020  123.991  spotify:track:06eFWpksA3M9qg8GeOGGBX
# 37     0.2610   0.5380  122.035  spotify:track:1gaByCFB1qArGJUIvgmolV
# 170    0.4200   0.0455  140.211  spotify:track:4EGMLBvaIIHNYuTQ3vyJmd
# 109    0.0906   0.3710  121.213  spotify:track:2n5rr23SVV4csieBxpGDvT
# 26     0.3310   0.0666  130.019  spotify:track:5xVKvk7TZeRSe4l8jTeZg4
# 33     0.3240   0.1120  103.989  spotify:track:5W5N23Xz1Zk6Qi8wkP8UPM
# 102    0.1760   0.5010   94.078  spotify:track:640VqmPmQyA4IoyzPxvUyA
# 236    0.1370   0.5690  143.115  spotify:track:7CYgSigpdaFuFUQNqNLHDq
# 47     0.1270   0.6090  145.765  spotify:track:4hFwJpN49gRhIXD967q3MB
# 46     0.3710   0.8180   81.290  spotify:track:5h233QfRh8YWjiF0RvZrqk
# 15     0.2950   0.5130  119.974  spotify:track:46NnMrWFwS0P6HyJ8tgNi8
# 14     0.1070   0.6920  134.987  spotify:track:7oqpMyBrfVsk5QBjDMhqOZ
# 125    0.1560   0.4310  148.033  spotify:track:46n0S3cNzNKAxAoI6O4569
# 23     0.3700   0.4290  192.281  spotify:track:0ELoAlQ3bOXzZuMGIVbnwc
# 13     0.0918   0.2380  106.029  spotify:track:5wM6LOw2U6XeIFHfsgI6wU
#
#     duration_ms  cluster
# 154      225495        0
# 37       515410        0
# 170      369880        0
# 109      268907        0
# 26       403707        0
# 33       206600        0
# 102      213446        0
# 236      172067        0
# 47       166853        0
# 46       184200        0
# 15       228533        0
# 14       172235        0
# 125      335550        0
# 23       120930        0
# 13       214104        0
#
# [15 rows x 21 columns]

# %%
#Create a funciton to classify every song in the user playlist to a cluster
def user_suggestion(user_df, fitted_metrics):
    user_sub = user_df[fitted_metrics]
    user_cluster = []
    
    for track in user_sub:
        user_cluster.append(kmeans.predict(np.array(track)))
        print(track)
    
    user_df['cluster'] = user_cluster
                            
    return user_df

# %% [markdown]
# ### Cosine Similarity

# %% [raw]
# Cosine Similarity will allow us to find the best song for the individuals playlist

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
test_song = np.array([[0.624, 0.886, 4, 6.046, 1, 0.0351, 0.1000, 0.941000, 0.0943, 0.772, 155.249]])

# %%
test_song
# Out:
# array([[6.24000e-01, 8.86000e-01, 4.00000e+00, 6.04600e+00, 1.00000e+00,
#         3.51000e-02, 1.00000e-01, 9.41000e-01, 9.43000e-02, 7.72000e-01,
#         1.55249e+02]])

# %%
reddit_array = reddit_features.to_numpy()
cos_sim = []
for track in reddit_array:
    similarity = cosine_similarity(np.array([track]), vibe.T.to_numpy())
    cos_sim.append(similarity)

# %%
list_cos_sim = []
for sublist in cos_sim:
    for item in sublist.tolist():
        list_cos_sim.append(item)

# %%
flat_cos_sim = []
for sublist in list_cos_sim:
    for item in sublist:
        flat_cos_sim.append(item)

# %%
reddit_df['cosine_sim'] = flat_cos_sim

# %%
top_tracks_reddit = reddit_df.sort_values(by = 'cosine_sim', ascending = False)

# %%
top_10 = top_tracks_reddit.head(10)

# %%
top_10.head()
# Out:
#         _id       created  upvotes  \
# 126  u49m9m  1.650034e+09       29
# 7    ud1sr0  1.651061e+09       11
# 52   u8w23n  1.650571e+09        2
# 211  txvgl8  1.649277e+09        2
# 37   uav6an  1.650808e+09      176
#
#                                                    url   subreddit  \
# 126  https://open.spotify.com/track/62lLZOUN0AmYBaw...  indieheads
# 7          https://www.youtube.com/watch?v=sWrZOhYgZ7c  indieheads
# 52   https://open.spotify.com/track/3Lz6teL5yOL4pp3...  indieheads
# 211  https://open.spotify.com/track/2S9ioeurLIMRV9X...  indieheads
# 37   https://open.spotify.com/track/1gaByCFB1qArGJU...  indieheads
#
#                      artist_all                 track  danceability  energy  \
# 126                      Caamp       Apple Tree Blues         0.537   0.649
# 7                  Post Animal            Cancer Moon         0.554   0.665
# 52                    Sick Joy   talking to the drugs         0.603   0.793
# 211             Charlie Hickey             Dandelions         0.619   0.479
# 37   DJ Sabrina The Teenage DJ               Call You         0.575   0.796
#
#      key  ...  mode  speechiness  acousticness  instrumentalness  liveness  \
# 126    8  ...     1       0.0308       0.51500          0.064100     0.119
# 7      5  ...     1       0.0367       0.00236          0.000238     0.117
# 52     6  ...     1       0.0402       0.00912          0.088600     0.392
# 211    6  ...     1       0.0369       0.71000          0.000125     0.171
# 37     6  ...     1       0.1410       0.18400          0.000000     0.261
#
#      valence    tempo                                   uri duration_ms  \
# 126    0.737  173.027  spotify:track:62lLZOUN0AmYBaw6es63l5      212680
# 7      0.477  111.969  spotify:track:3f11SOnd3uSZjf8WbTk773      231268
# 52     0.718  129.999  spotify:track:3Lz6teL5yOL4pp30hKj9LT      176799
# 211    0.627  128.071  spotify:track:2S9ioeurLIMRV9XIlsiBxS      218400
# 37     0.538  122.035  spotify:track:1gaByCFB1qArGJUIvgmolV      515410
#
#      cosine_sim
# 126    0.999989
# 7      0.999988
# 52     0.999988
# 211    0.999978
# 37     0.999978
#
# [5 rows x 21 columns]

# %%
top_10 = top_10[['artist_all', 'track', 'upvotes']]
top_10.rename(columns = {'artist_all': 'Artist(s)', 'track': 'Track', 'upvotes': 'Upvotes'}, inplace = True)
top_10.reset_index(inplace = True, drop = True)

# %%
top_10
# Out:
#                     Artist(s)                 Track  Upvotes
# 0                      Caamp       Apple Tree Blues       29
# 1                Post Animal            Cancer Moon       11
# 2                   Sick Joy   talking to the drugs        2
# 3             Charlie Hickey             Dandelions        2
# 4  DJ Sabrina The Teenage DJ               Call You      176
# 5     Pure Reason Revolution         Dead Butterfly        5
# 6                  easy life                BEESWAX       16
# 7                Ezra Furman      Book of Our Names       24
# 8      Melody's Echo Chamber                   Alma      101
# 9                  Carrtoons              Homegrown        2

# %%
top_10.to_csv('test_top10.csv', index = False)

# %%
reddit_df['cosine_sim'].describe()
# Out:
# count    263.000000
# mean       0.995788
# std        0.004202
# min        0.973435
# 25%        0.994994
# 50%        0.997293
# 75%        0.998266
# max        0.999550
# Name: cosine_sim, dtype: float64
